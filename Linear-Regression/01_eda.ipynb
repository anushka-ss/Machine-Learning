# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
import os
os.getcwd()

# %%
import os
os.listdir()

# %%
import os
print(os.listdir())

# %%
df = pd.read_csv("Student_Performance.csv")

# %%
df.corr(numeric_only=True)

# %%
df.columns

# %%
df.dtypes

# %%
print(df["Extracurricular Activities"].unique())

# %%
print(df["Extracurricular Activities"].head())
print(df.dtypes)

# %%
# Before signing x and y ,change the value use append
#DATA Cleaning and then assign the x and y

# %%
#SYNTAX:-
# x=df.drop(columns="target")
# y=df['target_col']

# %%
df["Extracurricular Activities"] = df["Extracurricular Activities"].map({
    "Yes": 1,
    "No": 0
})

# %%
x = df.drop(columns="Performance Index")
y = df["Performance Index"]

# %%
xtrain, xtest, ytrain, ytest = train_test_split(
    x, y, test_size=0.8,random_state=42
)#we can give any value but we should take random state is 42,the randomness is fixed,there is no proper reason for that but we should keep it constant.

# %%
print(xtrain)

# %%
from sklearn.linear_model import LinearRegression

# %%
#for creating the object
#  for cleaning the data
# to check the data is linear or non linear 
# train and split

#model creation
model=LinearRegression()

# %%
# Train the model
#fit is for updating the information about slope and intercept
model.fit(xtrain,ytrain)
