# %%
import pandas as pd
from sklearn.ensemble import IsolationForest

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
print(284807*0.05)
# Out:
# 14240.35

# %%
model = IsolationForest(
    n_estimators=100,
    max_samples=0.8,
    max_features=1.0,
    bootstrap=True,
    n_jobs=1,
    verbose=5,
    random_state=42,
    contamination=0.05 #5% #auto
    )
result = model.fit_predict(df)
anamolies = df[result==-1]
normal = df[result==1]
# Out:
# Building estimator 1 of 100 for this parallel run (total 100)...
# Building estimator 2 of 100 for this parallel run (total 100)...
# Building estimator 3 of 100 for this parallel run (total 100)...
# Building estimator 4 of 100 for this parallel run (total 100)...
# Building estimator 5 of 100 for this parallel run (total 100)...
# Building estimator 6 of 100 for this parallel run (total 100)...
# Building estimator 7 of 100 for this parallel run (total 100)...
# Building estimator 8 of 100 for this parallel run (total 100)...
# Building estimator 9 of 100 for this parallel run (total 100)...
# Building estimator 10 of 100 for this parallel run (total 100)...
# Building estimator 11 of 100 for this parallel run (total 100)...
# Building estimator 12 of 100 for this parallel run (total 100)...
# Building estimator 13 of 100 for this parallel run (total 100)...
# Building estimator 14 of 100 for this parallel run (total 100)...
# ...

# %%
set(result)
# Out:
# {np.int64(-1), np.int64(1)}

# %%
''' 
model = IsolationForest(
    n_estimators=100,
    max_samples=0.8,
    max_features=1.0,
    bootstrap=True,
    n_jobs=1,
    verbose=5
)
'''
# Out:
# ' \nmodel = IsolationForest(\n    n_estimators=100,\n    max_samples=0.8,\n    max_features=1.0,\n    bootstrap=True,\n    n_jobs=1,\n    verbose=5\n)\n'

# %%
df[result==-1]
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 48          35.0   1.386397  -0.794209  0.778224 -0.864708 -1.064132
# 51          36.0  -1.004929  -0.985978 -0.038039  3.710061 -6.631951
# 69          46.0  -1.923213  -0.870482  2.320170  1.988776  0.417091
# 82          52.0  -3.005237   2.600138  1.483691 -2.418473  0.306326
# ...          ...        ...        ...       ...       ...       ...
# 284770  172759.0  -0.822731   1.270140 -0.138566  0.479620  1.242101
# 284782  172767.0  -0.268061   2.540315 -1.400915  4.846661  0.639105
# 284795  172778.0 -12.516732  10.187818 -8.476671 -2.510473 -4.586669
# 284798  172782.0   0.219529   0.881246 -0.635891  0.960928 -0.152971
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
print(result)
result = result[:50]
# Out:
# [ 1  1 -1 ...  1  1  1]

# %%
df[result==1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28080\924683613.py in ?()
# ----> 1 df[result==1]
#
# c:\Users\Administrator\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    4094             return self.where(key)
#    4095
#    4096         # Do we have a (boolean) 1d indexer?
#    4097         if com.is_bool_indexer(key):
# -> 4098             return self._getitem_bool_array(key)
#    4099
#    4100         # We are left with two options: a single key, and a collection of keys,
#    4101         # We interpret tuples as collections only for non-MultiIndex
#
# c:\Users\Administrator\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    4144                 UserWarning,
#    4145                 stacklevel=find_stack_level(),
#    4146             )
# ...
