# %%
from sklearn.preprocessing import OrdinalEncoder
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.DataFrame({
    'cat_col1':['A','B','A','C','B','A','C','B','A','C'],
    'cat_col2':['X','Y','X','Z','Y','X','Z','Y','X','Z'],
    'label':    ['class0','class1','class2','class0','class1','class2','class0','class1','class2','class0']
})

# %%
x = df.drop(columns='label')
y = df['label']

# %%
xtrain, xtest, ytrain, ytest = train_test_split(
    x, y, train_size=0.8, random_state=42
)

# %%
xtrain
# Out:
#   cat_col1 cat_col2
# 5        A        X
# 0        A        X
# 7        B        Y
# 2        A        X
# 9        C        Z
# 4        B        Y
# 3        C        Z
# 6        C        Z

# %%
xtrain.shape

# 8 rows (samples)
# 2 columns (features)
# n_features = 2
# Out:
# (8, 2)

# %%
'''
encoder = OrdinalEncoder(categories=['cat_col1']) 
encoder.fit_transform(xtrain['cat_col1'])

#It is giving ValueError because categories should contain the actual category values, not the column name.

ValueError: Expected a 2-dimensional container but got <class 'pandas.Series'> instead. Pass a DataFrame containing a single row (i.e. single sample) or a single column (i.e. single feature) instead.

'''
# Out:
# "\nencoder = OrdinalEncoder(categories=['cat_col1']) \nencoder.fit_transform(xtrain['cat_col1'])\n\n#It is giving ValueError because categories should contain the actual category values, not the column name.\n\nValueError: Expected a 2-dimensional container but got <class 'pandas.Series'> instead. Pass a DataFrame containing a single row (i.e. single sample) or a single column (i.e. single feature) instead.\n\n"

# %%
print(xtrain['cat_col1'].shape) #OrdinalEncoder is designed to encode features (columns), so it always expects a 2D table but here its giving 1D array
# Out:
# (8,)

# %%
'''
encoder = OrdinalEncoder(categories=[['cat_col1']])
encoder.fit_transform(xtrain)

# Number of features in xtrain = 2
# Number of category lists provided = 1
# This is a mismatch.

ValueError: Shape mismatch: if categories is an array, it has to be of shape (n_features,).
'''
# Out:
# "\nencoder = OrdinalEncoder(categories=[['cat_col1']])\nencoder.fit_transform(xtrain)\n\n# Number of features in xtrain = 2\n# Number of category lists provided = 1\n# This is a mismatch.\n\nValueError: Shape mismatch: if categories is an array, it has to be of shape (n_features,).\n"

# %%
xtrain['cat_col1'].unique()
# Out:
# <ArrowStringArray>
# ['A', 'B', 'C']
# Length: 3, dtype: str

# %%
'''
encoder = OrdinalEncoder(categories=[['B','C']]) #1 
encoder.fit_transform(xtrain[['cat_col1']]) #2

ValueError: Found unknown categories ['A'] in column 0 during fit
'''
# Out:
# "\nencoder = OrdinalEncoder(categories=[['B','C']]) #1 \nencoder.fit_transform(xtrain[['cat_col1']]) #2\n\nValueError: Found unknown categories ['A'] in column 0 during fit\n"

# %%
encoder = OrdinalEncoder()
encoder.fit_transform(xtrain[['cat_col1']])
# Out:
# array([[0.],
#        [0.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [2.],
#        [2.]])

# %%
encoder = OrdinalEncoder(categories=[['B','C','A','D','A1']])
encoder.fit_transform(xtrain[['cat_col1']]) #ABC

#This means the encoder creates the mapping for 'D' and 'A1'
# Out:
# array([[2.],
#        [2.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [1.],
#        [1.]])

# %%
encoder =OrdinalEncoder(categories=[['B','C']],handle_unknown='use_encoded_value',unknown_value=-1)
encoder.fit_transform(xtrain[['cat_col1']]) #ABC
# Out:
# array([[-1.],
#        [-1.],
#        [ 0.],
#        [-1.],
#        [ 1.],
#        [ 0.],
#        [ 1.],
#        [ 1.]])

# %%
xtrain['cat_col2'].unique()
# Out:
# <ArrowStringArray>
# ['X', 'Y', 'Z']
# Length: 3, dtype: str

# %%
'''
encoder =OrdinalEncoder(categories=[['B','C'],['X','Y','Z']],handle_unknown='use_encoded_value',unknown_value=-1)
encoder.fit_transform(xtrain[['cat_col1']])

ValueError: Shape mismatch: if categories is an array, it has to be of shape (n_features,).
'''
# Out:
# "\nencoder =OrdinalEncoder(categories=[['B','C'],['X','Y','Z']],handle_unknown='use_encoded_value',unknown_value=-1)\nencoder.fit_transform(xtrain[['cat_col1']])\n\nValueError: Shape mismatch: if categories is an array, it has to be of shape (n_features,).\n"

# %%
print(xtest.columns)
# Out:
# Index(['cat_col1', 'cat_col2'], dtype='str')

# %%
encoder.transform(xtest[['cat_col1']])
# Out:
# array([[-1.],
#        [ 0.]])
