# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %%
df = pd.DataFrame({
    'col1':[1,0,np.nan,3,7],
    'col2':[20,25,np.nan,np.nan,30],
    'col3':['A','B',np.nan,'C','D']
})

# %%
df
# Out:
#    col1  col2 col3
# 0   1.0  20.0    A
# 1   0.0  25.0    B
# 2   NaN   NaN  NaN
# 3   3.0   NaN    C
# 4   7.0  30.0    D

# %%
# imputer = SimpleImputer(strategy="mean") #ValueError: Cannot use mean strategy with non-numeric data:could not convert string to float: 'A'

# %%
# imputer = SimpleImputer(strategy="median") #ValueError: Cannot use median strategy with non-numeric data:could not convert string to float: 'A'

# %%
# imputer = SimpleImputer(strategy="constant",fill_value=0) #fill_value=0--> only for contant

# %%
imputer = SimpleImputer(strategy="most_frequent")

# %%
imputer.fit_transform(df)
# Out:
# array([[1.0, 20.0, 'A'],
#        [0.0, 25.0, 'B'],
#        [0.0, 20.0, 'A'],
#        [3.0, 20.0, 'C'],
#        [7.0, 30.0, 'D']], dtype=object)

# %%
imputer.fit_transform(df[['col1','col2']]) #just for practice we are giving df but we need to use xtrain in projects
# Out:
# array([[ 1., 20.],
#        [ 0., 25.],
#        [ 0., 20.],
#        [ 3., 20.],
#        [ 7., 30.]])
