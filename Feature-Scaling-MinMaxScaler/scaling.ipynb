# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Salary.csv')

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  35 non-null     float64
#  1   Salary           35 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 692.0 bytes

# %%
x = df.drop(columns=['Salary'])   # Features
y = df['Salary']                  # Target

# %%
# Example-Single variable
# sns.boxplot(y=df['Salary'])

# Example-Categorical vs Numerical
# sns.boxplot(x='Department', y='Salary', data=df)

# Example-Multiple numerical columns
sns.boxplot(data=df[['YearsExperience', 'Salary']])
# Out:
# <Axes: >

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
standard_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()

# %%
xtrain[['YearsExperience']] = standard_scaler.fit_transform(xtrain[['YearsExperience']])

# %%
xtrain
# Out:
#     YearsExperience
# 12        -0.546291
# 8         -0.757273
# 16        -0.256192
# 9         -0.625410
# 33         1.800878
# 0         -1.311100
# 4         -1.021000
# 17        -0.203446
# 27         0.930579
# 5         -0.836391
# 11        -0.546291
# 1         -1.258354
# 2         -1.205609
# 32         1.642642
# 3         -1.073745
# 30         1.352542
# 23         0.561362
# 31         1.431660
# 10        -0.572664
# 22         0.482244
# 18        -0.045210
# 25         0.772343
# 6         -0.810018
# 20         0.192144
# 34         1.959114
# 7         -0.757273
# 14        -0.414428
# 28         1.115188

# %%
xtest[['YearsExperience']] = standard_scaler.transform(xtest[['YearsExperience']])

# %%
xtest
# Out:
#     YearsExperience
# 26         0.904207
# 13        -0.519919
# 24         0.693225
# 21         0.271262
# 15        -0.308937
# 29         1.167933
# 19        -0.018838

# %%
xtrain[['YearsExperience']].mean()
# Out:
# YearsExperience    4.758099e-17
# dtype: float64

# %%
xtrain[['YearsExperience']].std()
# Out:
# YearsExperience    1.01835
# dtype: float64
